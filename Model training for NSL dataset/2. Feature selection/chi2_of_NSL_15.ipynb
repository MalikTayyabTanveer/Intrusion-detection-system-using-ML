# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d01f0013-fab0-4f41-8c84-c9196ad58029" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d01f0013-fab0-4f41-8c84-c9196ad58029">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('NSL_KDD_Preprocessed.csv')

# %%
df.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       20     9        491          0     0
# 1         0              2       44     9        146          0     0
# 2         0              1       49     5          0          0     0
# 3         0              1       24     9        232       8153     0
# 4         0              1       24     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# ...

# %%
X = df.drop('label', axis=1)
y = df['label']
X.shape, y.shape
# Out:
# ((148517, 41), (148517,))

# %%
# Choose the number of top features you want to select
k = 15  # You can change this value based on your requirements

# Initialize the SelectKBest object with the chi2 scoring function
chi2_selector = SelectKBest(chi2, k=k)

# Fit the selector to your data
X_new = chi2_selector.fit_transform(X, y)

# %%
X_new.shape
# Out:
# (148517, 15)

# %%
print(X_new)
# Out:
# [[  0.  20.   9. ...  25.   0.   0.]
#  [  0.  44.   9. ...   1.   0.   0.]
#  [  0.  49.   5. ...  26.   1.   1.]
#  ...
#  [  0.  24.   9. ... 255.   0.   0.]
#  [  0.  12.   9. ... 252.   0.   0.]
#  [  0.  57.   1. ...  21.   0.   0.]]

# %%
# Get the selected feature indices
selected_features_indices = chi2_selector.get_support(indices=True)
print(selected_features_indices)
# Out:
# [ 0  2  3  4  5 11 12 15 22 24 25 31 32 37 38]

# %%
# Get the names of the selected features
selected_features = X.columns[selected_features_indices]
print(selected_features)
# Out:
# Index(['duration', 'service', 'flag', 'src_bytes', 'dst_bytes', 'logged_in',
#        'lnum_compromised', 'lnum_root', 'count', 'serror_rate',
#        'srv_serror_rate', 'dst_host_count', 'dst_host_srv_count',
#        'dst_host_serror_rate', 'dst_host_srv_serror_rate'],
#       dtype='object')

# %%
# Create a new DataFrame with the selected features
selected_features_df = df[selected_features]
print(selected_features_df)
# Out:
#         duration  service  flag  src_bytes  dst_bytes  logged_in  \
# 0              0       20     9        491          0          0
# 1              0       44     9        146          0          0
# 2              0       49     5          0          0          0
# 3              0       24     9        232       8153          1
# 4              0       24     9        199        420          1
# ...          ...      ...   ...        ...        ...        ...
# 148512         0       54     9        794        333          1
# 148513         0       24     9        317        938          1
# 148514         0       24     9      54540       8314          1
# 148515         0       12     9         42         42          0
# 148516         0       57     1          0          0          0
#
#         lnum_compromised  lnum_root  count  serror_rate  srv_serror_rate  \
# 0                      0          0      2          0.0              0.0
# ...

# %%
selected_features_df.head()
# Out:
#    duration  service  flag  src_bytes  dst_bytes  logged_in  lnum_compromised  \
# 0         0       20     9        491          0          0                 0
# 1         0       44     9        146          0          0                 0
# 2         0       49     5          0          0          0                 0
# 3         0       24     9        232       8153          1                 0
# 4         0       24     9        199        420          1                 0
#
#    lnum_root  count  serror_rate  srv_serror_rate  dst_host_count  \
# 0          0      2          0.0              0.0             150
# 1          0     13          0.0              0.0             255
# 2          0    123          1.0              1.0             255
# 3          0      5          0.2              0.2              30
# 4          0     30          0.0              0.0             255
#
#    dst_host_srv_count  dst_host_serror_rate  dst_host_srv_serror_rate
# ...

# %%
selected_features_df['labels'] = y
# Out:
# <ipython-input-13-930ec1460547>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_features_df['labels'] = y

# %%
selected_features_df.head()
# Out:
#    duration  service  flag  src_bytes  dst_bytes  logged_in  lnum_compromised  \
# 0         0       20     9        491          0          0                 0
# 1         0       44     9        146          0          0                 0
# 2         0       49     5          0          0          0                 0
# 3         0       24     9        232       8153          1                 0
# 4         0       24     9        199        420          1                 0
#
#    lnum_root  count  serror_rate  srv_serror_rate  dst_host_count  \
# 0          0      2          0.0              0.0             150
# 1          0     13          0.0              0.0             255
# 2          0    123          1.0              1.0             255
# 3          0      5          0.2              0.2              30
# 4          0     30          0.0              0.0             255
#
#    dst_host_srv_count  dst_host_serror_rate  dst_host_srv_serror_rate  labels
# ...

# %%
selected_features_df.to_csv('NSL_KDD_chi2_15.csv', index = False)

# %%
files.download('NSL_KDD_chi2_15.csv')
